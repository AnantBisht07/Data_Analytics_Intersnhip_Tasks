# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)

# %%
df = pd.read_csv('iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
plt.plot('SepalLengthCm','Species',data=df)
plt.show()

# %%
df.groupby('Species').size().plot(kind='bar',
                                 figsize = (6,6),
                                 title = 'TOTAL SPECIES',
                                 color='blue')
plt.show()

# %% [markdown]
# ###### This Bar graph showing the sum ofSepalLength for each species in the dataframe.

# %%
df.groupby('Species').sum()['SepalLengthCm'].plot(kind='bar',
                                                 figsize=(5,5),
                                                 color='red')
plt.show()

# %% [markdown]
# ##### As We can see that the mean SepalLengthCm is highest for the virginica species, followed by the versicolor species, and lowest for the setosa species.

# %%
df.groupby('Species').mean()['SepalLengthCm'].plot(kind='bar',
                                                 figsize=(5,5),
                                                  color='blue')
plt.show()

# %%
df.groupby('Id').mean()['SepalLengthCm'].plot(kind='bar',
                                                  color='blue')
plt.show()

# %% [markdown]
# ###### This bar graph showing the Total size of the Id datatframe.

# %%
df.groupby('Id').size().plot(kind='bar',
                                 figsize = (6,6),
                                 title = 'TOTAL Ids',
                                 color='yellow')
plt.show()

# %%
df.plot.bar(x='Species')
plt.show()

# %% [markdown]
# ###### This Pie chart showing the size of SepalWidthCm

# %%
df.groupby('SepalWidthCm').size().plot(kind='pie',
                                      figsize=(16,1))
plt.show()

# %% [markdown]
# ###### This pie bar graph showing the Mean of SepalWidthCm for each Species in the dataframe.

# %%
df.groupby('Species').mean()['SepalWidthCm'].plot(kind='bar',
                                                 figsize=(5,5))
plt.show()

# %% [markdown]
# ###### Here we get to know that Iris setosa is having more sepalwidth comparing with others.

# %%
df.groupby('Species').sum()['SepalWidthCm'].plot(kind='bar',
                                                 figsize=(5,5),
                                                color='blue')
plt.show()

# %%
df.groupby('Species').mean().plot(kind='bar',
                                      figsize=(8,8))
plt.show()

# %%
df.groupby('Species').mean()['PetalLengthCm'].plot(kind='pie',
                                                 figsize=(5,5))
plt.show()

# %%
df.head(6)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa

# %% [markdown]
# ###### here Iris Virginica is having more Petallength comparing with others.

# %%
df.groupby('Species').sum()['PetalLengthCm'].plot(kind='bar',color='magenta')
plt.show()

# %%
plt.scatter(df['SepalLengthCm'],df['SepalWidthCm'])
plt.show()

# %%
plt.stackplot(df['PetalLengthCm'],df['PetalWidthCm'],colors=['green','yellow'])
plt.show()

# %%
df.groupby('PetalWidthCm').size().plot(kind='bar')
plt.show()

# %%
df.groupby('Species').sum()['PetalWidthCm'].plot(kind='pie')
plt.show()

# %% [markdown]
# ###### This scatter plot showing the length of Id and Species

# %%
sns.scatterplot(x='Id',y='Species',data=df,color='green')
plt.show()

# %%
sns.lineplot(x='Id',y='PetalWidthCm',data=df)
plt.show()

# %%
sns.lineplot(x='SepalLengthCm',y='SepalWidthCm',hue='Species',data=df,palette='gist_earth')
plt.show()

# %% [markdown]
# ###### This lineplot showing the length of PetalLengthCm & PetalWidthCm wrt species

# %%
sns.lineplot(x='PetalLengthCm', y='PetalWidthCm', data=df, hue='Species', palette='gist_rainbow')
plt.grid()
plt.show()

# %% [markdown]
# ###### This lineplot is showing the Petallength versus the Species in the dataframe

# %%
sns.lineplot(x='Species',y='PetalLengthCm',data=df)
plt.show()

# %% [markdown]
# ##### This is showing the Scatter plot of Petallength versusthe Id in the dataframe.

# %%
plt.scatter(df['Id'], df['PetalLengthCm'],c='green')
plt.show()

# %% [markdown]
# ##### This is showing the scatter plot of Sepallength versus the Id in the dataframe

# %%
plt.scatter(df['Id'], df['SepalLengthCm'],c='magenta')
plt.show()

# %% [markdown]
# ###### This bar graph showing the sum of Sepallength for each value in petallength

# %%
df.groupby('PetalLengthCm').sum()['SepalLengthCm'].plot(kind='bar',
                                                     figsize=(6,6),
                                                     color= 'black')
plt.show()

# %% [markdown]
# ##### This Bar Graph is showing the sum of sepalwidth for each value in the petalwidth

# %%
df.groupby('PetalWidthCm').sum()['SepalWidthCm'].plot(kind='bar',
                                                     figsize=(6,6),
                                                     color= 'blue')
plt.show()
